# %% [markdown]
# # Exploratory Data Analysis
#
# Londoni jalgrattarendi andmete esmane analüüs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# TODO: Load processed data
# time_series = pd.read_parquet('..data/processed/time_series.parquet')
